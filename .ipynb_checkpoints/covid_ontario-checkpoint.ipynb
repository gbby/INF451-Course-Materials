# %%
# comparisons
# https://docs.google.com/spreadsheets/u/1/d/e/2PACX-1vTX5x2nxCde90Zwo83cdixZsyd_hU1orGsGYKpDe344wHeFi9MqI71aZYC6GLjOV_P2lp6_lUoacPNa/pubhtml?gid=1467787327&single=true
# https://twitter.com/jkwan_md/status/1312035412274221058?s=21
# https://russell-pollari.github.io/ontario-covid19/

import pandas as pd
import numpy as np
import urllib, json
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from mpl_toolkits.mplot3d import Axes3D
# from mpl_toolkits.basemap import Basemap
from matplotlib.collections import PolyCollection
import seaborn as sns
import datetime as dt
import geopandas as gpd
import folium
from shapely.geometry import Point, Polygon

# set the standard plot size
plt.rcParams['figure.figsize']=(30,15)

# %%
# get the "Confirmed positive cases of COVID19 in Ontario" data
# https://data.ontario.ca/dataset/confirmed-positive-cases-of-covid-19-in-ontario/resource/455fd63b-603d-4608-8216-7d8647f43350
# import data using the ontario open data API
# make sure to check the limit against current cases
url = "https://data.ontario.ca/en/api/3/action/datastore_search?resource_id=455fd63b-603d-4608-8216-7d8647f43350&limit=75000"
response = urllib.request.urlopen(url)
data = json.loads(response.read().decode('utf-8'))

# use this if you want to see the json
# print (data['result']['records'])

# use this if you want to write it to a pandas dataframe
df = pd.DataFrame(data['result']['records'])

# %%
# get the "Status of COVID-19 Cases in Ontario" data
# https://data.ontario.ca/dataset/status-of-covid-19-cases-in-ontario
# make sure to check the limit against current cases
url = "https://data.ontario.ca/en/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11&limit=75000"
response = urllib.request.urlopen(url)
data = json.loads(response.read().decode('utf-8'))

# use this if you want to see the json
# print (data['result']['records'])

status_df = pd.DataFrame(data['result']['records'])

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69331 entries, 0 to 69330
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        69331 non-null  int64
#  1   Row_ID                     69331 non-null  int64
#  2   Accurate_Episode_Date      69329 non-null  object
#  3   Case_Reported_Date         69330 non-null  object
#  4   Test_Reported_Date         68369 non-null  object
#  5   Specimen_Date              46081 non-null  object
#  6   Age_Group                  69331 non-null  object
#  7   Client_Gender              69331 non-null  object
#  8   Case_AcquisitionInfo       69331 non-null  object
#  9   Outcome1                   69331 non-null  object
#  10  Outbreak_Related           69331 non-null  object
#  11  Reporting_PHU              69331 non-null  object
#  12  Reporting_PHU_Address      69331 non-null  object
#  13  Reporting_PHU_City         69331 non-null  object
#  14  Reporting_PHU_Postal_Code  69331 non-null  object
#  15  Reporting_PHU_Website      69331 non-null  object
#  16  Reporting_PHU_Latitude     69331 non-null  float64
#  17  Reporting_PHU_Longitude    69331 non-null  float64
# dtypes: float64(2), int64(2), object(14)
# memory usage: 9.5+ MB
#    _id  Row_ID Accurate_Episode_Date   Case_Reported_Date  \
# 0    1       1   2020-10-12T00:00:00  2020-10-17T00:00:00
# 1    2       2   2020-10-11T00:00:00  2020-10-13T00:00:00
# 2    3       3   2020-10-20T00:00:00  2020-10-22T00:00:00
# 3    4       4   2020-10-21T00:00:00  2020-10-22T00:00:00
# 4    5       5   2020-10-10T00:00:00  2020-10-15T00:00:00
#
#     Test_Reported_Date        Specimen_Date Age_Group Client_Gender  \
# 0  2020-10-17T00:00:00  2020-10-16T00:00:00       50s        FEMALE
# 1  2020-10-13T00:00:00  2020-10-12T00:00:00       40s        FEMALE
# 2  2020-10-22T00:00:00  2020-10-21T00:00:00       20s        FEMALE
# 3  2020-10-22T00:00:00  2020-10-21T00:00:00       20s          MALE
# 4  2020-10-15T00:00:00  2020-10-10T00:00:00       20s        FEMALE
#
#   Case_AcquisitionInfo      Outcome1 Outbreak_Related  \
# 0                   CC  Not Resolved
# 1                   CC      Resolved
# 2  Missing Information  Not Resolved
# 3                   CC  Not Resolved
# 4    No known epi link  Not Resolved
#
#                          Reporting_PHU   Reporting_PHU_Address  \
# 0   York Region Public Health Services      17250 Yonge Street
# 1                   Peel Public Health  7120 Hurontario Street
# 2   York Region Public Health Services      17250 Yonge Street
# 3  Simcoe Muskoka District Health Unit       15 Sperling Drive
# 4        Haldimand-Norfolk Health Unit     12 Gilbertson Drive
#
#   Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0          Newmarket                   L3Y 6Z1
# 1        Mississauga                   L5W 1N4
# 2          Newmarket                   L3Y 6Z1
# 3             Barrie                   L4M 6K9
# 4             Simcoe                   N3Y 4N5
#
#                       Reporting_PHU_Website  Reporting_PHU_Latitude  \
# 0  www.york.ca/wps/portal/yorkhome/health/                44.048023
# 1                 www.peelregion.ca/health/               43.647471
# 2  www.york.ca/wps/portal/yorkhome/health/                44.048023
# 3               www.simcoemuskokahealth.org               44.410713
# 4                              www.hnhu.org               42.847825
#
#    Reporting_PHU_Longitude
# 0               -79.480239
# 1               -79.708893
# 2               -79.480239
# 3               -79.686306
# 4               -80.303815

# %%
status_df.info()
status_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 19 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   _id                                                       262 non-null    int64
#  1   Reported Date                                             262 non-null    object
#  2   Confirmed Negative                                        47 non-null     float64
#  3   Presumptive Negative                                      12 non-null     float64
#  4   Presumptive Positive                                      25 non-null     float64
#  5   Confirmed Positive                                        260 non-null    float64
#  6   Resolved                                                  250 non-null    float64
#  7   Deaths                                                    222 non-null    float64
#  8   Total Cases                                               260 non-null    float64
#  9   Total patients approved for testing as of Reporting Date  256 non-null    float64
#  10  Total tests completed in the last day                     193 non-null    float64
#  11  Under Investigation                                       262 non-null    int64
#  12  Number of patients hospitalized with COVID-19             206 non-null    float64
#  13  Number of patients in ICU with COVID-19                   206 non-null    float64
#  14  Number of patients in ICU on a ventilator with COVID-19   206 non-null    float64
#  15  Total Positive LTC Resident Cases                         159 non-null    float64
#  16  Total Positive LTC HCW Cases                              157 non-null    float64
#  17  Total LTC Resident Deaths                                 159 non-null    float64
#  18  Total LTC HCW Deaths                                      159 non-null    float64
# dtypes: float64(16), int64(2), object(1)
# memory usage: 39.0+ KB
#    _id        Reported Date  Confirmed Negative  Presumptive Negative  \
# 0    1  2020-01-26T00:00:00                 NaN                   NaN
# 1    2  2020-01-27T00:00:00                 NaN                   NaN
# 2    3  2020-01-28T00:00:00                 NaN                   NaN
# 3    4  2020-01-30T00:00:00                 NaN                   NaN
# 4    5  2020-01-31T00:00:00                 NaN                   NaN
#
#    Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 0                   1.0                 NaN       NaN     NaN          NaN
# 1                   2.0                 NaN       NaN     NaN          NaN
# 2                   1.0                 1.0       NaN     NaN          1.0
# 3                   0.0                 2.0       NaN     NaN          2.0
# 4                   0.0                 2.0       NaN     NaN          2.0
#
#    Total patients approved for testing as of Reporting Date  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total tests completed in the last day  Under Investigation  \
# 0                                    NaN                    9
# 1                                    NaN                   19
# 2                                    NaN                   11
# 3                                    NaN                   27
# 4                                    NaN                   17
#
#    Number of patients hospitalized with COVID-19  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Number of patients in ICU with COVID-19  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Number of patients in ICU on a ventilator with COVID-19  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total Positive LTC Resident Cases  Total Positive LTC HCW Cases  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    Total LTC Resident Deaths  Total LTC HCW Deaths
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN

# %%
# sort by date
df = df.sort_values(by=['Accurate_Episode_Date'], ascending=False);
status_df = status_df.sort_values(by=['Reported Date'], ascending=True);

# %%
# see how many new cases are reported today in the "confirmed positive" dataset (make sure to change value to today's date)
# keep in mind that the numbers are always missing the most recent day or two
today = df[df['Accurate_Episode_Date'].str.contains("2020-10-23", na=False)]
today.head()
# Out:
#          _id  Row_ID Accurate_Episode_Date   Case_Reported_Date  \
# 6670    6657    6657   2020-10-23T00:00:00  2020-10-23T00:00:00
# 10371  10351   10351   2020-10-23T00:00:00  2020-10-23T00:00:00
# 9433    9410    9410   2020-10-23T00:00:00  2020-10-23T00:00:00
# 2355    2350    2350   2020-10-23T00:00:00  2020-10-23T00:00:00
# 4161    4154    4154   2020-10-23T00:00:00  2020-10-23T00:00:00
#
#         Test_Reported_Date        Specimen_Date Age_Group Client_Gender  \
# 6670   2020-10-23T00:00:00  2020-10-22T00:00:00       50s          MALE
# 10371                 None                 None       30s          MALE
# 9433   2020-10-21T00:00:00  2020-10-20T00:00:00       20s          MALE
# 2355   2020-10-23T00:00:00  2020-10-21T00:00:00       50s          MALE
# 4161   2020-10-23T00:00:00  2020-10-22T00:00:00       30s          MALE
#
#       Case_AcquisitionInfo      Outcome1 Outbreak_Related  \
# 6670   Missing Information  Not Resolved
# 10371  Missing Information  Not Resolved
# 9433   Missing Information  Not Resolved
# 2355   Missing Information  Not Resolved
# 4161   Missing Information  Not Resolved
#
#                              Reporting_PHU   Reporting_PHU_Address  \
# 6670    York Region Public Health Services      17250 Yonge Street
# 10371  Simcoe Muskoka District Health Unit       15 Sperling Drive
# 9433                    Peel Public Health  7120 Hurontario Street
# 2355    York Region Public Health Services      17250 Yonge Street
# 4161    York Region Public Health Services      17250 Yonge Street
#
#       Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 6670           Newmarket                   L3Y 6Z1
# 10371             Barrie                   L4M 6K9
# 9433         Mississauga                   L5W 1N4
# 2355           Newmarket                   L3Y 6Z1
# 4161           Newmarket                   L3Y 6Z1
#
#                           Reporting_PHU_Website  Reporting_PHU_Latitude  \
# 6670   www.york.ca/wps/portal/yorkhome/health/                44.048023
# 10371               www.simcoemuskokahealth.org               44.410713
# 9433                  www.peelregion.ca/health/               43.647471
# 2355   www.york.ca/wps/portal/yorkhome/health/                44.048023
# 4161   www.york.ca/wps/portal/yorkhome/health/                44.048023
#
#        Reporting_PHU_Longitude
# 6670                -79.480239
# 10371               -79.686306
# 9433                -79.708893
# 2355                -79.480239
# 4161                -79.480239

# %%
# set the dates to datetime64 for later use
df["Accurate_Episode_Date"] = df["Accurate_Episode_Date"].astype("datetime64")
df["Case_Reported_Date"] = df["Case_Reported_Date"].astype("datetime64")
df["Test_Reported_Date"] = df["Test_Reported_Date"].astype("datetime64")
df["Specimen_Date"] = df["Specimen_Date"].astype("datetime64")

# %%
# for accurate daily totals, better to use the "status of covid cases" dataset
# you'll need to create a new column for daily growth in cases
status_df['New Cases'] = status_df['Total Cases'].diff(periods=1).fillna(0)

# %%
status_df.tail()
# Out:
#      _id        Reported Date  Confirmed Negative  Presumptive Negative  \
# 257  258  2020-10-20T00:00:00                 NaN                   NaN
# 258  259  2020-10-21T00:00:00                 NaN                   NaN
# 259  260  2020-10-22T00:00:00                 NaN                   NaN
# 260  261  2020-10-23T00:00:00                 NaN                   NaN
# 261  262  2020-10-24T00:00:00                 NaN                   NaN
#
#      Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 257                   NaN              6237.0   56606.0  3053.0      65896.0
# 258                   NaN              6299.0   57325.0  3062.0      66686.0
# 259                   NaN              6390.0   58066.0  3071.0      67527.0
# 260                   NaN              6474.0   58799.0  3080.0      68353.0
# 261                   NaN              6821.0   59424.0  3086.0      69331.0
#
#      Total patients approved for testing as of Reporting Date  \
# 257                                          4714326.0
# 258                                          4746972.0
# 259                                          4785832.0
# 260                                          4825851.0
# 261                                          4870002.0
#
#      Total tests completed in the last day  Under Investigation  \
# 257                                24049.0                24129
# 258                                32646.0                29332
# 259                                38860.0                34784
# 260                                40019.0                35436
# 261                                44151.0                30922
#
#      Number of patients hospitalized with COVID-19  \
# 257                                          274.0
# 258                                          260.0
# 259                                          270.0
# 260                                          276.0
# 261                                          294.0
#
#      Number of patients in ICU with COVID-19  \
# 257                                     72.0
# 258                                     71.0
# 259                                     74.0
# 260                                     78.0
# 261                                     82.0
#
#      Number of patients in ICU on a ventilator with COVID-19  \
# 257                                               45.0
# 258                                               49.0
# 259                                               48.0
# 260                                               47.0
# 261                                               53.0
#
#      Total Positive LTC Resident Cases  Total Positive LTC HCW Cases  \
# 257                             6442.0                        2772.0
# 258                             6462.0                        2781.0
# 259                             6487.0                        2785.0
# 260                             6524.0                        2796.0
# 261                             6607.0                        2805.0
#
#      Total LTC Resident Deaths  Total LTC HCW Deaths  New Cases
# 257                     1979.0                   8.0      821.0
# 258                     1981.0                   8.0      790.0
# 259                     1984.0                   8.0      841.0
# 260                     1987.0                   8.0      826.0
# 261                     1989.0                   8.0      978.0

# %%
# plot cases by public health unit
fig = plt.figure()
fig.suptitle('COVID-19 Cases by Public Health Unit', fontsize=25) # Add the text/suptitle to figure

ax = df['Reporting_PHU'].value_counts().plot(
    kind='barh', 
    figsize=(14,8)
)
ax.set_xlabel("Public Health Unit", fontsize=16)
ax.set_ylabel("Cases Reported by PHU", fontsize=16)
ax.tick_params(axis='both', labelsize=14)

# if you want to save your graph
# fig.savefig('PHU.jpg')

# %%
# use matplotlib to plot reported cases from the "conpos" dataset
fig = plt.figure()
fig.suptitle('Ontario COVID-19 Reported Cases', fontsize=24) # Add the text/suptitle to figure

counts = df['Case_Reported_Date'].value_counts()
plt.bar(counts.index,counts)

# ax.set_xlabel("Public Health Unit", fontsize=16)
# ax.set_ylabel("Cases Reported by PHU", fontsize=16)
# ax.tick_params(axis='both', labelsize=14)
plt.show()

# %%
# same thing, but using seaborn lets us plot a kernel density estimate (which can visually stand in for a running average)
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html

sns.set()
ax = sns.histplot(df['Case_Reported_Date'], kde=True, bins=300)

# %%
# use matplotlib to plot actual new cases based on reported change in the "Status of COVID" dataset
fig = plt.figure()
fig.suptitle('Ontario COVID-19 Reported Cases', fontsize=24) # Add the text/suptitle to figure

y = status_df['New Cases']
x = status_df['Reported Date']
#plt.bar(counts.index,counts)

# plt.plot(x, y) # line plot
plt.fill_between(x, y) # area plot
plt.tick_params(axis ='x', rotation = 90)
plt.xticks(np.arange(0, 300, 50))

plt.show()

# %%
# using seaborn's barplot
g = sns.barplot(x="Reported Date", y="New Cases",  data=status_df)
g.set(xticks=[]);

# g.fig.set_size_inches(30,15) # and we'll use this to change the figure size

# %%
# using seaborn's displot method
g = sns.displot(df, x="Accurate_Episode_Date", kde=True, bins=300)
g.set_xticklabels(rotation=90)
# g.fig.set_size_inches(30,15) # and we'll use this to change the figure size (already done in cell 1)

# %%
# comparisons based on gender
g = sns.displot(df, x="Accurate_Episode_Date", hue="Client_Gender", kde=True, bins=300)
g.set_xticklabels(rotation=90)
g.fig.set_size_inches(20,10)

# %%
# side-by-side comparison based on gender
g = sns.displot(df, x="Accurate_Episode_Date", hue="Client_Gender", col="Client_Gender", kde=True)
g.set_xticklabels(rotation=90)
sns.set(font_scale=1.3) # seaborn's method for setting fontsize is pretty dumb
g.fig.set_size_inches(20,10)

# %% [markdown]
# # And what else might we consider visualizing while we're at it? Maybe age group by gender...

# %%
# or how about age group x outcome
df = df.replace(['<20'],'10s') # either re-set the order, or re-name <20 to something like 10s
df = df.sort_values('Age_Group', ascending=True) 

g = sns.displot(df, x="Age_Group", hue="Outcome1", multiple="dodge")
g.set_xticklabels(rotation=90)
g.fig.set_size_inches(20,10)

# %% [markdown]
# # Some things to fix:
#
# * Re-order x axis (seaborn won't order age groups by default)
# * Increase fonts (or change default matplotlib/seaborn options at the top of my notebook)
# * Change colour palettes
# * Make sure my H x W ratios are appropriate (see here: https://stats.stackexchange.com/questions/185346/what-is-the-best-ratio-between-width-and-height-in-a-bar-chart)
# * Get rid of the NaNs in the dataset
# * Make some more space between the age categories

# %%
# add moving averages
fig = plt.figure()
fig.suptitle('Ontario COVID-19 Reported Cases', fontsize=24) # Add the text/suptitle to figure

# variables for x and y axes
y = status_df['New Cases']
x = status_df['Reported Date']

# create some rolling averages
rolling_mean5 = y.rolling(window=5).mean()
rolling_mean7 = y.rolling(window=7).mean()

#plt.bar(counts.index,counts)
#plt.bar(x, y, color='burlywood')
plt.fill_between(x, y, color='burlywood') # area plot
plt.plot(x, rolling_mean5, label='5 Day SMA', color='red')
plt.plot(x, rolling_mean7, label='7 Day SMA', color='green')
plt.tick_params(axis ='x', rotation = 90)
plt.xticks(np.arange(0, 300, 50))
plt.legend(loc='upper left')
plt.show()
